# %%
from pathlib import Path
import sys

# Add the project root directory to sys.path
sys.path.append(str(Path().resolve().parent))
from src.constants.paths import SECRET_PATH


from src.elasticsearch.indexer import Indexer
from src.processing.pde_ple import PDE, es
from src.constants.constants import S3_RAW_DOCS_PATH

# Récupérer tous les fichiers S3
file_paths = PDE.s3.list_objects("s3://bkt-pud-uc/uc202-rex/ZZZ - Test REX FLA3/")
# Out:
# Secrets chargés avec succès !
# /opt/app-root/src/uc202-ipn-rex/.venv/lib/python3.11/site-packages/elasticsearch/_sync/client/__init__.py:397: SecurityWarning: Connecting to 'https://noeyyalp.noe.edf.fr:29203' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
from collections import defaultdict
extension_counts = defaultdict(int)

# Iterate over each file path and count the extensions
for path in file_paths:
    # Split the path by '.' and get the last element to extract the file extension
    extension = path.split(".")[-1]
    extension_counts[extension] += 1

# Convert the defaultdict to a regular dictionary
extension_counts = dict(extension_counts)

# Print the counts of each file extension
print(extension_counts)
# Out:
# {'xls': 36, 'doc': 409, 'ppt': 106, 'zip': 5, 'pdf': 183, 'PPT': 2, 'pptx': 116, 'xlsx': 19, 'docx': 78, 'tmp': 9, 'PPTX': 2}

# %%
txt_paths=[path for path in file_paths if path[-3::]=='txt']

# %%
from pathlib import Path
import sys

# Add the project root directory to sys.path
sys.path.append(str(Path().resolve().parent))
from src.constants.paths import SECRET_PATH


from src.elasticsearch.indexer import Indexer
from src.processing.pde_ple import PDE, es
from src.constants.constants import S3_RAW_DOCS_PATH

# Récupérer tous les fichiers S3
file_paths = PDE.s3.list_objects("s3://bkt-pud-uc/uc202-rex/ZZZ - Test REX FLA3/")

# %%
file_paths = [fp for fp in file_paths if fp.lower().endswith(".pdf")]
file_paths = file_paths[:1]

# %%
es.indices.create(index="uc202-rex-gsimon")
# Out:
# /opt/app-root/src/uc202-ipn-rex/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'noeyyalp.noe.edf.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'uc202-rex-gsimon'})

# %%
indexer = Indexer(
    es,
    file_paths,
    index_name="uc202-rex-gsimon",
    raw_path="s3://bkt-pud-uc/uc202-rex/ZZZ - Test REX FLA3_raw_files_txt/",
)

# %%
for file_path in file_paths:
    indexer.process_file(
        file_path,
        raw_path="s3://bkt-pud-uc/uc202-rex/ZZZ - Test REX FLA3_raw_files_txt/",
    )
# Out:
# /opt/app-root/src/uc202-ipn-rex/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'noeyyalp.noe.edf.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /opt/app-root/src/uc202-ipn-rex/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'noeyyalp.noe.edf.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
